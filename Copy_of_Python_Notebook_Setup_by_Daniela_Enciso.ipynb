# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielaEG/Python-Notebook-Research/blob/main/Copy_of_Python_Notebook_Setup_by_Daniela_Enciso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Research Question # 1: Is there an association between the amount of times an adult made you feel unwanted and avoiding your life problems?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='https://drive.google.com/file/d/1IbHzUMYKFBkmW3TIvryP7XJlW-WkmGEw/view?usp=sharing'
path= 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)
df.head()
# Out:
#        AID  BIO_SEX        agew1 IMONTH4 IDAY4 IYEAR4   MACNO4 INTID4  \
# 0  5710027        2
# 1  5710131        2  19.42739726       5     6   2008  2288160    160
# 2  5710317        1
# 3  5710386        1  20.43013699       5    22   2008  2288238    238
# 4  5710455        2
#
#   BIO_SEX4 VERSION4  ... H4EO5C H4EO5D H4EO5E H4EO5F H4EO5G H4EO5H H4EO5I  \
# 0                    ...
# 1        2     V5.4  ...      0      0      0      0      0      0      0
# 2                    ...
# 3        1     V5.4  ...      0      0      0      0      0      0      0
# 4                    ...
#
#   H4EO5J H4EO6 H4EO7
# 0
# 1      0     2     1
# 2
# 3      0     4     1
# 4
#
# [5 rows x 976 columns]

# %% [markdown]
# Codebook 1
#
# ![Screenshot 2023-04-30 at 9.06.49 PM.png](data:image/png;base64,...)

# %%
#Manage data for variable 1

# %%
df['H4MA1'].value_counts()
# Out:
# 6     2668
#       1390
# 5      617
# 3      537
# 1      516
# 2      471
# 4      225
# 98      52
# 96      28
# Name: H4MA1, dtype: int64

# %%
df['Felt_Unwanted']= df['H4MA1']
df['Felt_Unwanted'].value_counts()
# Out:
# 6     2668
#       1390
# 5      617
# 3      537
# 1      516
# 2      471
# 4      225
# 98      52
# 96      28
# Name: Felt_Unwanted, dtype: int64

# %%
df['Felt_Unwanted'] = df['Felt_Unwanted'].loc[ df['Felt_Unwanted'] !=' ']
df['Felt_Unwanted'].value_counts()
# Out:
# 6     2668
# 5      617
# 3      537
# 1      516
# 2      471
# 4      225
# 98      52
# 96      28
# Name: Felt_Unwanted, dtype: int64

# %%
df['Felt_Unwanted'] = df['Felt_Unwanted'].loc[ df['Felt_Unwanted'] !='96']
df['Felt_Unwanted'] = df['Felt_Unwanted'].loc[ df['Felt_Unwanted'] !='98']
df['Felt_Unwanted'].value_counts()
# Out:
# 6    2668
# 5     617
# 3     537
# 1     516
# 2     471
# 4     225
# Name: Felt_Unwanted, dtype: int64

# %%
df['Felt_Unwanted'].replace(['5','3','1','2','4','6'], ['MORE THAN TEN','THREE TO FIVE','ONE','TWO','SIX TO TEN','NEVER HAPPENED'] , inplace= True)
df['Felt_Unwanted'].value_counts()
# Out:
# NEVER HAPPENED    2668
# MORE THAN TEN      617
# THREE TO FIVE      537
# ONE                516
# TWO                471
# SIX TO TEN         225
# Name: Felt_Unwanted, dtype: int64

# %%
pip install researchPy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import researchpy as rp

# %%
rp.summary_cat(df['Felt_Unwanted'])
# Out:
#         Variable         Outcome  Count  Percent
# 0  Felt_Unwanted  NEVER HAPPENED   2668    53.00
# 1                  MORE THAN TEN    617    12.26
# 2                  THREE TO FIVE    537    10.67
# 3                            ONE    516    10.25
# 4                            TWO    471     9.36
# 5                     SIX TO TEN    225     4.47

# %%
#Graphs and tables or statistics

# %%
df['Felt_Unwanted'] = df['H4MA1']

# %%
df['Felt_Unwanted'] = df['Felt_Unwanted'].loc[ df['Felt_Unwanted'] !=' ']
df['Felt_Unwanted'] = df['Felt_Unwanted'].loc[ df['Felt_Unwanted'] !='96']
df['Felt_Unwanted'] = df['Felt_Unwanted'].loc[ df['Felt_Unwanted'] !='98']
df['Felt_Unwanted'].value_counts()
# Out:
# 6    2668
# 5     617
# 3     537
# 1     516
# 2     471
# 4     225
# Name: Felt_Unwanted, dtype: int64

# %%
df['Felt_Unwanted'].replace(['1','2','3','4','5','6'] , ['One time', 'Two times', 'Three to Five','Six to Ten','More than Ten','Never Happened'], inplace = True)
df['Felt_Unwanted'].value_counts()
# Out:
# Never Happened    2668
# More than Ten      617
# Three to Five      537
# One time           516
# Two times          471
# Six to Ten         225
# Name: Felt_Unwanted, dtype: int64

# %%
df['Felt_Unwanted'].value_counts().plot(kind ='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Felt_Unwanted'>

# %%
plt.xlabel("Amount of Times Felt Unwanted")
plt.ylabel("Percent")
plt.title("how often did a parent or other adult caregiver say things that made you feel unwanted?")
df['Felt_Unwanted'].value_counts(normalize = True).plot(kind ='barh', color = 'red', width = 0.2, alpha = 0.5)
# Out:
# <Axes: title={'center': 'how often did a parent or other adult caregiver say things that made you feel unwanted?'}, ylabel='Percent'>

# %% [markdown]
# Codebook 2:
# ![Screenshot 2023-04-30 at 10.49.15 PM.png](data:image/png;base64,...)

# %%
#Manage data for variable 1

# %%
df['H4PE33'].value_counts()
# Out:
# 4    2637
#      1391
# 3    1040
# 2     814
# 5     458
# 1     151
# 8       8
# 6       5
# Name: H4PE33, dtype: int64

# %%
df['Avoid_Problems']= df['H4PE33']
df['Avoid_Problems'].value_counts()
# Out:
# 4    2637
#      1391
# 3    1040
# 2     814
# 5     458
# 1     151
# 8       8
# 6       5
# Name: Avoid_Problems, dtype: int64

# %%
df['Avoid_Problems'] = df['Avoid_Problems'].loc[ df['Avoid_Problems'] !=' ']
df['Avoid_Problems'].value_counts()
# Out:
# 4    2637
# 3    1040
# 2     814
# 5     458
# 1     151
# 8       8
# 6       5
# Name: Avoid_Problems, dtype: int64

# %%
df['Avoid_Problems'] = df['Avoid_Problems'].loc[ df['Avoid_Problems'] !='8']
df['Avoid_Problems'] = df['Avoid_Problems'].loc[ df['Avoid_Problems'] !='.']
df['Avoid_Problems'].value_counts()
# Out:
# 4    2637
# 3    1040
# 2     814
# 5     458
# 1     151
# 6       5
# Name: Avoid_Problems, dtype: int64

# %%
df['Avoid_Problems'].replace(['4','3','2','5','1','6'], ['DISAGREE','AGREE NOR DISAGREE','AGREE','STRONGLY DISAGREE','STRONGLY AGREE','NEVER HAPPENED'] , inplace= True)
df['Avoid_Problems'].value_counts()
# Out:
# DISAGREE              2637
# AGREE NOR DISAGREE    1040
# AGREE                  814
# STRONGLY DISAGREE      458
# STRONGLY AGREE         151
# NEVER HAPPENED           5
# Name: Avoid_Problems, dtype: int64

# %%
rp.summary_cat(df['Avoid_Problems'])
# Out:
#          Variable             Outcome  Count  Percent
# 0  Avoid_Problems            DISAGREE   2637    51.66
# 1                  AGREE NOR DISAGREE   1040    20.37
# 2                               AGREE    814    15.95
# 3                   STRONGLY DISAGREE    458     8.97
# 4                      STRONGLY AGREE    151     2.96
# 5                      NEVER HAPPENED      5     0.10

# %%
#Graphs and tables or statistics

# %%
df['H4PE33'].value_counts()
# Out:
# 4    2637
#      1391
# 3    1040
# 2     814
# 5     458
# 1     151
# 8       8
# 6       5
# Name: H4PE33, dtype: int64

# %%
df['Avoid_Problems'] = df['H4PE33']

# %%
df['Avoid_Problems'] = df['Avoid_Problems'].loc[ df['Avoid_Problems'] !=' ']
df['Avoid_Problems'] = df['Avoid_Problems'].loc[ df['Avoid_Problems'] !='8']
df['Avoid_Problems'] = df['Avoid_Problems'].loc[ df['Avoid_Problems'] !='.']
df['Avoid_Problems'].value_counts()
# Out:
# 4    2637
# 3    1040
# 2     814
# 5     458
# 1     151
# 6       5
# Name: Avoid_Problems, dtype: int64

# %%
df['Avoid_Problems'].replace(['1','2','3','4','5','6'] , ['Strongly Agree', 'Agree', 'Neither','Disagree','Strongly Disagree','Never Happened'], inplace = True)
df['Avoid_Problems'].value_counts()
# Out:
# Disagree             2637
# Neither              1040
# Agree                 814
# Strongly Disagree     458
# Strongly Agree        151
# Never Happened          5
# Name: Avoid_Problems, dtype: int64

# %%
df['Avoid_Problems'].value_counts().plot(kind ='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Avoid_Problems'>

# %%
plt.xlabel("Amount of Avoided Problems")
plt.ylabel("Percent")
plt.title("I go out of my way to avoid having to deal with problems in my life")
df['Avoid_Problems'].value_counts(normalize = True).plot(kind ='barh', color = 'red', width = 0.2, alpha = 0.5)
# Out:
# <Axes: title={'center': 'I go out of my way to avoid having to deal with problems in my life'}, ylabel='Percent'>
